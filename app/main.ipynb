# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Task 0
# Read the dataset from csv file & perform data cleaning - remove all rows, which contains `?` in some columns.
# Also check for data correctness (salary & salary $K).

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("../data/adult.csv")
df_clean = df.replace("?", np.nan).dropna()
df_clean.head()
invalid_salary = df_clean[
    ((df_clean["salary"] == "<=50K") & (df_clean["salary K$"] > 50)) |
    ((df_clean["salary"] == ">50K") & (df_clean["salary K$"] <= 50))
]


assert invalid_salary.empty, "Salary and salary K$ are inconsistent"

# %% [markdown]
# # Task 1
# Print the count of men and women in the dataset.

# %%
import numpy as np
import pandas as pd

gender_counts = df_clean["sex"].value_counts()
print(gender_counts)
# Out:
# sex
# Male      20380
# Female     9782
# Name: count, dtype: int64

# %% [markdown]
# # Task 2
# Find the average age of men in dataset

# %%
import numpy as np
import pandas as pd

average_age_man = df_clean[df_clean["sex"] == "Male"]["age"].mean()

# %% [markdown]
# # Task 3
# Get the percentage of people from Poland (native-country)

# %%
import numpy as np
import pandas as pd

total = len(df_clean)
poland_count = len(df_clean[df_clean["native-country"] == "Poland"])
percentage_poland = poland_count / total * 100

# %% [markdown]
# # Task 4
# Get the mean and standard deviation of the age for people who earn > 50K per year. After this, get it for those who earn <= 50K.

# %%
import numpy as np
import pandas as pd

mean_age_high = df_clean[df_clean["salary"] == ">50K"]["age"].mean()
std_age_high = df_clean[df_clean["salary"] == ">50K"]["age"].std()

mean_age_low = df_clean[df_clean["salary"] == "<=50K"]["age"].mean()
std_age_low = df_clean[df_clean["salary"] == "<=50K"]["age"].std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 mean_age_high
#
# NameError: name 'mean_age_high' is not defined

# %% [markdown]
# # Task 5
# Check, if there are some people without higher education (education: Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters, Doctorate), but with > 50K salary

# %%
import numpy as np
import pandas as pd

higher_education = [ 'Bachelors', 'Prof-school', 'Assoc-acdm', 'Assoc-voc', 'Masters', 'Doctorate' ]
people = df_clean[
    (~df_clean['education'].isin(df_clean['education'].value_counts().index)) &
    (df_clean['salary'] == '>50K')
]

# %% [markdown]
# # Task 6
# Get the statistics of age for each type of education. Use `groupby` and `describe` for this.

# %%
import numpy as np
import pandas as pd

education_stat = df_clean.groupby("education")["age"].describe()

# %% [markdown]
# # Task 7
# Compare the married and non-married men salaries. Who earns more? (>50K or <=50K)
# Married men are those, whom `marital-status` starts with "Married". Others are not.

# %%
import numpy as np
import pandas as pd

married_men = df_clean[(df_clean["sex"] == "Male") & (df_clean["marital-status"].str.startswith("Married"))]
not_married_men = df_clean[(df_clean["sex"] == "Male") & (~df_clean["marital-status"].str.startswith("Married"))]
married_salary_counts = married_men['salary'].value_counts()
not_married_salary_counts = non_married_men['salary'].value_counts()
married_salary_counts / married_salary_counts.sum()
not_married_salary_counts / not_married_salary_counts.sum()

# %% [markdown]
# # Task 8
# Get the max hours per week some person works. How many people works the same amount of hours per week?

# %%
import numpy as np
import pandas as pd

max_hours = df_clean['hours-per-week'].max()
people_with_max_hours = df_clean[df_clean['hours-per-week'] == max_hours].shape[0]

# %% [markdown]
# # Task 9
# Analyze the correlation between data in dataset. Understand connected fields in it and print highlight thier connection.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = df_clean.corr(numeric_only=True)
print(corr_matrix)

corr_matrix.style.background_gradient(cmap='coolwarm')
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
